# %% [markdown]
# <a href="https://colab.research.google.com/github/Parinita-Jain/M_L/blob/main/Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("Automobile_data.csv")
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   body-style         205 non-null    object
#  5   drive-wheels       205 non-null    object
#  6   engine-location    205 non-null    object
#  7   width              205 non-null    float64
#  8   height             205 non-null    float64
#  9   engine-type        205 non-null    object
#  10  engine-size        205 non-null    int64
#  11  horsepower         205 non-null    object
#  12  city-mpg           205 non-null    int64
#  13  highway-mpg        205 non-null    int64
#  14  price              205 non-null    int64
# dtypes: float64(2), int64(5), object(8)
# ...

# %% [markdown]
# Univariate Ananlysis

# %%
# 1 plt.figure(figsize=(10,8))
df[['engine-size','horsepower','price']].hist(figsize=(10,8),bins=6,color="Yellow")
# 2 plt.figure(figsize=(10,8))
plt.tight_layout()
plt.show()

# %% [markdown]
# Findings
#
# Most of the car has a  Engine Size is inrange 60 to 190
# Most vehicle has horsepower 50 to 125
# Most Vehicle are in price range 5000 to 12000

# %% [markdown]
# LinePlot using Seaborn

# %%
x=np.arange(10)
y=np.sqrt(x)

sns.lineplot(x,y)

plt.grid(True)
plt.show()

# %% [markdown]
# DistPlot - The Distplot depicts the data by a histogram and a line in combination to it

# %%
sns.distplot(df['price'])

# %% [markdown]
# Plotting mean and median on a Distribution Plot

# %%
mwidth=df['width'].mean()
dwidth=df['width'].median()

sns.distplot(df['width'])

plt.axvline(mwidth,color='r')
plt.axvline(dwidth,color='y')
plt.grid(True)

# %% [markdown]
# Countplot

# %%
sns.countplot(data=df,x='body-style')
plt.grid=(True)

# %%
plt.figure(figsize=(8,10))
sns.countplot(data=df,y="make")
plt.grid=(True)

# %%
sns.countplot(data=df,x="fuel-type")

# %%
sns.countplot(data=df,x='body-style',hue='fuel-type')

# %%
plt.figure(1)
plt.subplot(221)
df['engine-type'].value_counts(normalize=True).plot(figsize=(10,8),kind='bar',color='red')
plt.title("Number of Engine Type frequency diagram")
plt.ylabel('Number of Engine Type')
plt.xlabel('engine-type');


plt.subplot(222)
df['drive-wheels'].value_counts(normalize=True).plot(figsize=(10,8),kind='bar',color='green')
plt.title("Number of Drive Wheels frequency diagram")
plt.ylabel('Number of Drive Wheels')
plt.xlabel('num-of-drive-wheels');

plt.subplot(223)
df['fuel-type'].value_counts(normalize= True).plot(figsize=(10,8),kind='bar',color='purple')
plt.title("Number of Fuel Type frequency diagram")
plt.ylabel('Number of vehicles')
plt.xlabel('fuel-type');

plt.subplot(224)
df['body-style'].value_counts(normalize=True).plot(figsize=(10,8),kind='bar',color='orange')
plt.title("Number of Body Style frequency diagram")
plt.ylabel('Number of vehicles')
plt.xlabel('body-style');
plt.tight_layout()
plt.show()

# %% [markdown]
# Findings
#
# More than 70 % of the vehicle has Ohc type of Engine.
# 57% of the cars has 4 doors.
# Gas is preferred by 85 % of the vehicles.
# Most produced vehicle are of body style sedan around 48% followed by hatchback 32%.

# %%
explode=[0,0,0.2,0,0.1]
df['body-style'].value_counts().plot(figsize=(6, 6),kind='pie',explode=explode,autopct='%.2f')

plt.title("Fuel type pie diagram")
plt.ylabel('Number of vehicles')
plt.xlabel('Fuel type');

# %%
df.corr()
# Out:
#              symboling     width    height  engine-size  city-mpg  \
# symboling     1.000000 -0.232919 -0.541038    -0.105790 -0.035823
# width        -0.232919  1.000000  0.279210     0.735433 -0.642704
# height       -0.541038  0.279210  1.000000     0.067149 -0.048640
# engine-size  -0.105790  0.735433  0.067149     1.000000 -0.653658
# city-mpg     -0.035823 -0.642704 -0.048640    -0.653658  1.000000
# highway-mpg   0.034606 -0.677218 -0.107358    -0.677470  0.971337
# price        -0.085781  0.718253  0.132444     0.852995 -0.654611
#
#              highway-mpg     price
# symboling       0.034606 -0.085781
# width          -0.677218  0.718253
# height         -0.107358  0.132444
# engine-size    -0.677470  0.852995
# city-mpg        0.971337 -0.654611
# highway-mpg     1.000000 -0.679048
# price          -0.679048  1.000000

# %%
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_154ab_row0_col0, #T_154ab_row1_col1, #T_154ab_row2_col2, #T_154ab_row3_col3, #T_154ab_row4_col4, #T_154ab_row5_col5, #T_154ab_row6_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_154ab_row0_col1 {
#   background-color: #cccfe5;
#   color: #000000;
# }
# #T_154ab_row0_col2, #T_154ab_row1_col5, #T_154ab_row2_col0, #T_154ab_row3_col4, #T_154ab_row3_col5, #T_154ab_row5_col1, #T_154ab_row5_col3, #T_154ab_row5_col6, #T_154ab_row6_col4, #T_154ab_row6_col5 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_154ab_row0_col3, #T_154ab_row2_col5 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_154ab_row0_col4, #T_154ab_row5_col0 {
#   background-color: #a7bddb;
#   color: #000000;
# }
# #T_154ab_row0_col5 {
#   background-color: #93b5d6;
#   color: #000000;
# }
# #T_154ab_row0_col6 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_154ab_row1_col0 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# ...

# %% [markdown]
# Heatmap

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(),annot=True,cmap="Blues")

# %%
plt.figure(figsize=(8,8))
sns.heatmap(df.corr(),annot=True,cmap="viridis")

# %%
import seaborn as sns
corr = df.corr()
plt.figure(figsize=(20,9))
a = sns.heatmap(corr, annot=True, fmt='.2f')

# %% [markdown]
# Findings
#
# curb-size, engine-size, horsepower are positively corelated.
# city-mpg,highway-mpg are negatively corelated

# %%
# following are the attriputer that show positive correlation

plt.figure(figsize = (12,8))

sns.heatmap(df.corr(),annot = True, cmap='Blues', mask = (df.corr() <= 0.7 ))
plt.show()

# %%
# following are the attriputer that show negative correlation

plt.figure(figsize = (12,8))

sns.heatmap(df.corr(),annot = True, cmap='Blues', mask = (df.corr() >= 0 ))
plt.show()

# %% [markdown]
# Bivaraite Analysis

# %%
plt.rcParams['figure.figsize']=(23,10)
ax = sns.boxplot(x="make", y="price", data=df)

# %%
plt.rcParams['figure.figsize']=(19,7)
ax = sns.boxplot(x="body-style", y="price", data=df)

# %%
plt.rcParams['figure.figsize']=(10,5)
ax = sns.boxplot(x="drive-wheels", y="price", data=df)

# %% [markdown]
# Findings
#
# Mercedez-Benz ,BMW, Jaguar, Porshe produces expensive cars more than 25000.
# cheverolet,dodge, honda,mitbushi, nissan,plymouth subaru,toyata produces budget models with lower prices.
# most of the cars comapany produces car in range below 25000.
# Hardtop model are expensive in prices followed by convertible and sedan body style.
# Turbo models have higher prices than for the standard model.
# Convertible has only standard edition with expensive cars.
# hatchback and sedan turbo models are available below 20000.
# rwd wheel drive vehicle have expensive prices

# %% [markdown]
# Scatterplot

# %%
sns.scatterplot(data=df,x="engine-size",y="price")

# %%
sns.scatterplot(data=df,x="width",y="price")

# %%
sns.scatterplot(data=df,x="highway-mpg",y="price")

# %% [markdown]
# Pairplot:
#
# Diagonally from top left to right, the plots represent univariate distribution of data for the variable in that column.
# Other plots represent the pairwise scatter plots between different variables.

# %% [markdown]
# Features correlation: Assess pairwise relationships between three or more variables. This is important to understand relationships between different features when building machine learning model.
# Multicollinearity: Assess the collinearity / multi-collinearity by analyzing the correlation between two or more variables. Recall that multi-collinearity can result in two or more predictor variables that might be providing the same information about the response variable thereby leading to unreliable coefficients of the predictor variables (especially for linear models).
# Data is linearly separable?: Assess whether the data is linearly separable or not. The data which is linearly separable can be separated using a linear line. The data which isn’t linearly separable would need to be applied with kernel methods. Thus, it may help determine machine learning algorithm one would want to use.

# %%
g = sns.pairplot(df[["city-mpg", "horsepower", "engine-size","price", "fuel-type"]], hue="fuel-type", diag_kind="hist")

# %% [markdown]
# Findings
#
# Vehicle Mileage decrease as increase in Horsepower , engine-size, Curb Weight.
# As horsepower increase the engine size increases.
# Curbweight increases with the increase in Engine Size

# %% [markdown]
# Price Analysis
#
# engine size and curb-weight is positively co realted with price.
# city-mpg is negatively corelated with price as increase horsepower reduces the mileage.
